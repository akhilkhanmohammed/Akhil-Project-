# %%
from xlwings.rest.api import api
import pandas as pd
import requests,json

# %%
base_url = 'http://192.168.0.5:5000'
endpoint = '/book/TableData.xlsm/names/akhil/range'

# %%
r = requests.get(base_url+endpoint)

# %%
data = r.json()
df = pd.DataFrame(data['formula'][0:],columns=data['formula'][0])

# %%
df
# Out:
#            Customer                   Branch Data                    \
# 0          Customer                   Branch Data
# 1     Customer Name  MD Akhil Khan      Zone Name      Kothagudem
# 2       Father Name  MD Aleem Khan    Region Name       Telangana
# 3  Customer Profile   Business Man      Area Name  Ramanji Colony
# 4  Loan Account No.    98989478983    Branch Name      Kothagudem
# 5
# 6
#
#    Customer Home Address Data                                         \
# 0  Customer Home Address Data
# 1                     PinCode                               507101
# 2                    LandMark                      Near PostOffice
# 3                    Address1  4-4-155, Ramanji Colony, Kothagudem
# 4                    Address2                     Telangana 507101
# 5
# 6
#
#    Customer Office Data                                         \
# 0  Customer Office Data
# 1       Office Pin Code                               507101
# 2      Office Land Mark                      Near PostOffice
# 3       Office Address1  4-4-155, Ramanji Colony, Kothagudem
# 4       Office Address2                     Telangana 507101
# 5
# 6
#
#            Loan Amount Data
# 0          Loan Amount Data
# 1            Agreement Date        44806
# 2  Loan Registration Number  78787474747
# 3                     Tenor  N Arunkumar
# 4               Advance EMI      5,500rs
# 5                       MOB     10,000rs
# 6
